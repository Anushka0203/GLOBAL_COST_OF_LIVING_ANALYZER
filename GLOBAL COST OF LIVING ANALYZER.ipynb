# %% [markdown]
# # ANALYZING COST OF LIVING IN DIFFERENT COUNTRIES #

# %% [markdown]
# ### Importing various libraries required ###

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import folium
from folium import Circle
from geopy import Nominatim
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Understanding the dataset ##
# ### Import the dataset into jupyter notebook ###

# %%
#reading the dataset
city=pd.read_csv('cost-of-living.csv')

# %% [markdown]
# ### Shape of the dataset indicating no. of rows and no. of columns ###

# %%
#checking the shape of the data
city.shape
# Out:
# (55, 161)

# %% [markdown]
# ### To check first 5 rows of the dataset ###

# %%
city.head()
# Out:
#                                           Unnamed: 0  \
# 0                       Meal, Inexpensive Restaurant
# 1  Meal for 2 People, Mid-range Restaurant, Three...
# 2     McMeal at McDonalds (or Equivalent Combo Meal)
# 3                  Domestic Beer (0.5 liter draught)
# 4                  Imported Beer (0.33 liter bottle)
#
#    Saint Petersburg, Russia  Istanbul, Turkey  Izmir, Turkey  \
# 0                      7.34              4.58           3.06
# 1                     29.35             15.28          12.22
# 2                      4.40              3.82           3.06
# 3                      2.20              3.06           2.29
# 4                      2.20              3.06           2.75
#
#    Helsinki, Finland  Chisinau, Moldova  Milan, Italy  Cairo, Egypt  \
# 0              12.00               4.67          15.0          3.38
# 1              65.00              20.74          60.0         17.48
# ...

# %% [markdown]
# ### Creating a locator object using Nominatim() and extracting location of any region using geocode()

# %%
#extracting latitude and longitude
locator=Nominatim(user_agent="myGeocoder")
location=locator.geocode("Saint Petersburg, Russia")

# %%
print("Latitude={}, Longitude={}".format(location.latitude, location.longitude))
# Out:
# Latitude=59.938732, Longitude=30.316229

# %% [markdown]
# ## Extracting latitude and longitude for all the 161 cities
# ### In order to do so, all the cities should fall under one varible or index in the table
# ### Hence, transposing the tabular matrix

# %%
city=city.T
city.head()
# Out:
#                                                     0   \
# Unnamed: 0                Meal, Inexpensive Restaurant
# Saint Petersburg, Russia                          7.34
# Istanbul, Turkey                                  4.58
# Izmir, Turkey                                     3.06
# Helsinki, Finland                                   12
#
#                                                                          1   \
# Unnamed: 0                Meal for 2 People, Mid-range Restaurant, Three...
# Saint Petersburg, Russia                                              29.35
# Istanbul, Turkey                                                      15.28
# Izmir, Turkey                                                         12.22
# Helsinki, Finland                                                        65
#
#                                                                       2   \
# Unnamed: 0                McMeal at McDonalds (or Equivalent Combo Meal)
# ...

# %% [markdown]
# ### Renaming the columns with the names of the items and dropping off the name of index[0] and renaming it with 'location'

# %%
city.rename(columns=city.iloc[0], inplace=True)
city.drop(city.index[0], inplace=True)
city.head()
# Out:
#                          Meal, Inexpensive Restaurant  \
# Saint Petersburg, Russia                         7.34
# Istanbul, Turkey                                 4.58
# Izmir, Turkey                                    3.06
# Helsinki, Finland                                  12
# Chisinau, Moldova                                4.67
#
#                          Meal for 2 People, Mid-range Restaurant, Three-course  \
# Saint Petersburg, Russia                                              29.35
# Istanbul, Turkey                                                      15.28
# Izmir, Turkey                                                         12.22
# Helsinki, Finland                                                        65
# Chisinau, Moldova                                                     20.74
#
#                          McMeal at McDonalds (or Equivalent Combo Meal)  \
# Saint Petersburg, Russia                                            4.4
# ...

# %%
city=city.reset_index()
#renaming index column to locations
city=city.rename(columns={'index': 'location'})
city.head()
# Out:
#                    location Meal, Inexpensive Restaurant  \
# 0  Saint Petersburg, Russia                         7.34
# 1          Istanbul, Turkey                         4.58
# 2             Izmir, Turkey                         3.06
# 3         Helsinki, Finland                           12
# 4         Chisinau, Moldova                         4.67
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              29.35
# 1                                              15.28
# 2                                              12.22
# 3                                                 65
# 4                                              20.74
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            4.4
# 1                                           3.82
# 2                                           3.06
# 3                                              8
# ...

# %%
city.columns
# Out:
# Index(['location', 'Meal, Inexpensive Restaurant',
#        'Meal for 2 People, Mid-range Restaurant, Three-course',
#        'McMeal at McDonalds (or Equivalent Combo Meal)',
#        'Domestic Beer (0.5 liter draught)',
#        'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
#        'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
#        'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
#        'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
#        'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
#        'Imported Beer (0.33 liter bottle)', 'Cigarettes 20 Pack (Marlboro)',
#        'One-way Ticket (Local Transport)',
#        'Chicken Breasts (Boneless, Skinless), (1kg)',
#        'Monthly Pass (Regular Price)', 'Gasoline (1 liter)', 'Volkswagen Golf',
#        'Apartment (1 bedroom) in City Centre',
#        'Apartment (1 bedroom) Outside of Centre',
#        'Apartment (3 bedrooms) in City Centre',
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
from geopy.extra.rate_limiter import RateLimiter

#convenient function to delay between geocoding calls
geocode=RateLimiter(locator.geocode, min_delay_seconds=1)

# %% [markdown]
# ### Creating longitude, latitude and altitude columns

# %%
#creating location columns
city['Location'] = city['location'].apply(geocode)

#create longitude, latitude and altitude from location column
city['point'] = city['Location'].apply(lambda loc: tuple(loc.point) if loc else None)

#split point column into longitude, latitude and altitude columns
city[['latitude', 'longitude', 'altitude']] = pd.DataFrame(city['point'].tolist(), index=city.index)

city.head()
# Out:
#                    location Meal, Inexpensive Restaurant  \
# 0  Saint Petersburg, Russia                         7.34
# 1          Istanbul, Turkey                         4.58
# 2             Izmir, Turkey                         3.06
# 3         Helsinki, Finland                           12
# 4         Chisinau, Moldova                         4.67
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              29.35
# 1                                              15.28
# 2                                              12.22
# 3                                                 65
# 4                                              20.74
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            4.4
# 1                                           3.82
# 2                                           3.06
# 3                                              8
# ...

# %%
city=city.drop(['Location', 'point', 'altitude'], axis=1)
city.columns
# Out:
# Index(['location', 'Meal, Inexpensive Restaurant',
#        'Meal for 2 People, Mid-range Restaurant, Three-course',
#        'McMeal at McDonalds (or Equivalent Combo Meal)',
#        'Domestic Beer (0.5 liter draught)',
#        'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
#        'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
#        'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
#        'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
#        'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
#        'Imported Beer (0.33 liter bottle)', 'Cigarettes 20 Pack (Marlboro)',
#        'One-way Ticket (Local Transport)',
#        'Chicken Breasts (Boneless, Skinless), (1kg)',
#        'Monthly Pass (Regular Price)', 'Gasoline (1 liter)', 'Volkswagen Golf',
#        'Apartment (1 bedroom) in City Centre',
#        'Apartment (1 bedroom) Outside of Centre',
#        'Apartment (3 bedrooms) in City Centre',
# ...

# %% [markdown]
# ## Aggregate the above items and create new features like food, lifestyle, etc that reflects similar items ##

# %%
def food(city):
    return int(round((city[['Meal, Inexpensive Restaurant','Domestic Beer (0.5 liter draught)',
       'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
       'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
       'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
       'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
       'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
       'Imported Beer (0.33 liter bottle)', 'Cigarettes 20 Pack (Marlboro)','Chicken Breasts (Boneless, Skinless), (1kg)','Apples (1kg)', 'Oranges (1kg)',
       'Potato (1kg)', 'Lettuce (1 head)', 'Cappuccino (regular)',
       'Rice (white), (1kg)', 'Tomato (1kg)', 'Banana (1kg)', 'Onion (1kg)',
       'Beef Round (1kg) (or Equivalent Back Leg Red Meat)']].mean())))

def travel(city):
    return int(round((city[['One-way Ticket (Local Transport)','Monthly Pass (Regular Price)', 'Gasoline (1 liter)','Taxi Start (Normal Tariff)', 'Taxi 1km (Normal Tariff)',
       'Taxi 1hour Waiting (Normal Tariff)']].mean())))

def living(city):
    return int(round((city[['Volkswagen Golf',
       'Apartment (1 bedroom) in City Centre',
       'Apartment (1 bedroom) Outside of Centre',
       'Apartment (3 bedrooms) in City Centre',
       'Apartment (3 bedrooms) Outside of Centre',
       'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment','Price per Square Meter to Buy Apartment in City Centre',
       'Price per Square Meter to Buy Apartment Outside of Centre','Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)']].mean())))

def lifestyle(city):
    return int(round((city[['Meal for 2 People, Mid-range Restaurant, Three-course',
       'McMeal at McDonalds (or Equivalent Combo Meal)','1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)',
       'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
       'Fitness Club, Monthly Fee for 1 Adult',
       'Tennis Court Rent (1 Hour on Weekend)',
       'Cinema, International Release, 1 Seat',
       '1 Pair of Jeans (Levis 501 Or Similar)',
       '1 Summer Dress in a Chain Store (Zara, H&M, ...)',
       '1 Pair of Nike Running Shoes (Mid-Range)',
       '1 Pair of Men Leather Business Shoes']].mean())))

def education(city):
    return int(round((city[['Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child',
       'International Primary School, Yearly for 1 Child']].mean())))

def income(city):
    return int(round((city[['Average Monthly Net Salary (After Tax)',
       'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate']].mean())))

# %% [markdown]
# ### Creating six new columns in the dataset

# %%
city['Food']=city.apply(food,axis=1)
city['Travel']=city.apply(travel,axis=1)
city['Living']=city.apply(living,axis=1)
city['Lifestyle']=city.apply(lifestyle,axis=1)
city['Education']=city.apply(education,axis=1)
city['Income']=city.apply(income,axis=1)

# %%
city.head()
# Out:
#                    location Meal, Inexpensive Restaurant  \
# 0  Saint Petersburg, Russia                         7.34
# 1          Istanbul, Turkey                         4.58
# 2             Izmir, Turkey                         3.06
# 3         Helsinki, Finland                           12
# 4         Chisinau, Moldova                         4.67
#
#   Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              29.35
# 1                                              15.28
# 2                                              12.22
# 3                                                 65
# 4                                              20.74
#
#   McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            4.4
# 1                                           3.82
# 2                                           3.06
# 3                                              8
# ...

# %% [markdown]
# ### Splitting country names from the location column

# %%
city['location'].str.split(', ')[0]
# Out:
# ['Saint Petersburg', 'Russia']

# %%
#split the location to fetch the country names
city['country']=city['location'].str.split(', ')

city['Country']=city['country'].apply(lambda x: x[1])

city['Country'].value_counts()
# Out:
# India         11
# Canada         8
# Poland         6
# Romania        5
# Australia      5
#               ..
# Estonia        1
# Uzbekistan     1
# Slovenia       1
# Sri Lanka      1
# Slovakia       1
# Name: Country, Length: 90, dtype: int64

# %% [markdown]
# ## Comparing Factors in different countries
# ### Countries with dark yellow colour have more prices than others

# %%
#groupby countries by lifestyle factors
city[['Country','Food','Travel','Living','Lifestyle','Education','Income']].groupby(['Country']).agg('mean').style.background_gradient(cmap='Wistia')
# Out:
# <style  type="text/css" >
# #T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow0_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow5_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow8_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow20_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow25_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow36_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow37_col2,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow38_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow40_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow53_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow56_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow57_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow76_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow78_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow79_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow80_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow84_col0,#T_baf46c70_d713_11eb_bf05_f8a2d6d10edbrow85_col0{
#             background-color:  #ffc908;
# ...

# %%
#checking out top 5 most expensive countries in all categories
plt.rcParams['figure.figsize']=(17,7)

plt.subplot(2,3,1)
x=city[['Country','Food']].sort_values(by='Food', ascending=False).head(5)
sns.barplot(x['Country'],x['Food'],palette='viridis')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.subplot(2,3,2)
x=city[['Country','Travel']].sort_values(by='Travel', ascending=False).head(5)
sns.barplot(x['Country'],x['Travel'],palette='viridis')
plt.xticks(rotation=16)
plt.xlabel(' ')

plt.subplot(2,3,3)
x=city[['Country','Living']].sort_values(by='Living', ascending=False).head(6)
sns.barplot(x['Country'],x['Living'],palette='viridis')
plt.xticks(rotation=15)
plt.xlabel(' ')

plt.subplot(2,3,4)
x=city[['Country','Lifestyle']].sort_values(by='Lifestyle', ascending=False).head(5)
sns.barplot(x['Country'],x['Lifestyle'],palette='viridis')
plt.xticks(rotation=15)
plt.xlabel(' ')

plt.subplot(2,3,5)
x=city[['Country','Education']].sort_values(by='Education', ascending=False).head(5)
sns.barplot(x['Country'],x['Education'],palette='viridis')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.subplot(2,3,6)
x=city[['Country','Income']].sort_values(by='Income', ascending=False).head(6)
sns.barplot(x['Country'],x['Income'],palette='viridis')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.suptitle('Most Expensive countries (Expenses in Euro)', fontsize=20)
plt.show()

# %%
#checking out least 5 expensive countries in all categories
plt.rcParams['figure.figsize']=(17,7)

plt.subplot(2,3,1)
x=city[['Country','Food']].sort_values(by='Food', ascending=True).head(5)
sns.barplot(x['Country'],x['Food'],palette='Reds')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.subplot(2,3,2)
x=city[['Country','Travel']].sort_values(by='Travel', ascending=True).head(9)
sns.barplot(x['Country'],x['Travel'],palette='Reds')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.subplot(2,3,3)
x=city[['Country','Living']].sort_values(by='Living', ascending=True).head(9)
sns.barplot(x['Country'],x['Living'],palette='Reds')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.subplot(2,3,4)
x=city[['Country','Lifestyle']].sort_values(by='Lifestyle', ascending=True).head(18)
sns.barplot(x['Country'],x['Lifestyle'],palette='Reds')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.subplot(2,3,5)
x=city[['Country','Education']].sort_values(by='Education', ascending=True).head(9)
sns.barplot(x['Country'],x['Education'],palette='Reds')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.subplot(2,3,6)
x=city[['Country','Income']].sort_values(by='Income', ascending=True).head(6)
sns.barplot(x['Country'],x['Income'],palette='Reds')
plt.xticks(rotation=5)
plt.xlabel(' ')

plt.suptitle('Least Expensive countries (Expenses in Euro)', fontsize=20)
plt.show()

# %%
top_range=(city.describe().loc['min',:]/city.describe().loc['max',:]).sort_values().index[2:22]
list(top_range)
# Out:
# ['Education', 'Travel', 'Income', 'Food', 'Living', 'Lifestyle']

# %% [markdown]
# ## Performing Geo-spatial Analysis

# %%
def color_producer(val):
    if val<=city[item].quantile(.25):
        return 'forestgreen'
    elif val<=city[item].quantile(.50):
        return 'goldenrod'
    elif val<=city[item].quantile(.75):
        return 'darkred'
    else:
        return 'red'

# %% [markdown]
# ### Making bubble map to the base map using folium library

# %%
map=folium.Map(location=[city['latitude'].mean(), city['longitude'].mean()], tiles='Stamen Terrain', zoom_start=2)
item=top_range[1]

#adding bubble map to the base map
for i in range(0,len(city)):
    Circle(
            location=[city.iloc[i]['latitude'], city.iloc[i]['longitude']],
            radius=120000,
            color=color_producer(city.iloc[i][item])).add_to(map)
print('Price of: ',item)
map
# Out:
# Price of:  Travel
# ...

# %% [markdown]
# ## Comparing different lifestyle factors
# ### Using heatmap function wherein data values are graphically represented and are depicted by various colours

# %%
plt.rcParams['figure.figsize']=(15,5)
plt.style.use('fivethirtyeight')

sns.heatmap(city[['Food','Travel','Living','Lifestyle','Education','Income']].corr(),
           cmap='magma', annot=True, linecolor='violet',linewidths=20)
plt.title('Correlation between major life style factors', fontsize=20)
plt.show()

# %% [markdown]
# ## Comparing lifestyle factors in different countries

# %%
city[(city['Country']=='India') | (city['Country']=='United Kingdom') | (city['Country']=='Australia') | (city['Country']=='Germany') | (city['Country']=='China') | (city['Country']=='Russia')][['location','Food','Travel','Living','Lifestyle','Education','Income']].set_index('location').sort_values(by='Income',ascending=False).style.background_gradient(cmap='copper')
# Out:
# <style  type="text/css" >
# #T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow0_col0,#T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow0_col5,#T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow1_col0,#T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow3_col1,#T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow3_col2,#T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow5_col3,#T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow7_col3,#T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow11_col4{
#             background-color:  #ffc77f;
#             color:  #000000;
#         }#T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow0_col1,#T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow6_col1{
#             background-color:  #b8744a;
#             color:  #000000;
#         }#T_cf3d4f6c_d713_11eb_9e5b_f8a2d6d10edbrow0_col2{
#             background-color:  #3a2517;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# ## Comparing Lifestyle factors in Indian Cities

# %%
#Comparing Indian cities
city['City']=city['location'].str.split(', ')
city['City']=city['City'].apply(lambda x: x[0])

x=city[city['Country']=='India']

# %%
plt.rcParams['figure.figsize']=(15,15)
plt.subplot(3,2,1)
sns.barplot(y=x['City'],x=x['Travel'],palette='viridis')
plt.ylabel(" ")

plt.subplot(3,2,2)
sns.barplot(y=x['City'],x=x['Living'],palette='viridis')
plt.ylabel(" ")

plt.subplot(3,2,3)
sns.barplot(y=x['City'],x=x['Lifestyle'],palette='viridis')
plt.ylabel(" ")

plt.subplot(3,2,4)
sns.barplot(y=x['City'],x=x['Education'],palette='viridis')
plt.ylabel(" ")

plt.subplot(3,2,5)
sns.barplot(y=x['City'],x=x['Income'],palette='viridis')
plt.ylabel(" ")

plt.suptitle("Comparision of Indian Cities", fontsize=20)
plt.show()

# %%
#finding the list of the most expensive countries to live in
x=city[['Food','Travel','Living','Lifestyle','Education','Income']]
a=MinMaxScaler()
data=a.fit_transform(x)
data=pd.DataFrame(data)
data.columns=x.columns
data.head()
# Out:
#        Food    Travel    Living  Lifestyle  Education    Income
# 0  0.142857  0.194444  0.139139   0.372549   0.139049  0.074890
# 1  0.142857  0.138889  0.161588   0.156863   0.177913  0.043424
# 2  0.142857  0.111111  0.155125   0.078431   0.121129  0.036816
# 3  0.428571  0.527778  0.252539   0.568627   0.032424  0.346759
# 4  0.142857  0.027778  0.082583   0.333333   0.057568  0.018250

# %% [markdown]
# ## Ranking Places based on their cost of living

# %%
data['Total Score']=(data['Food']+data['Travel']+data['Living']+data['Lifestyle']+data['Education']+data['Income'])/6

#concat city
cities=city[['City','Country']]
data=pd.concat([data,cities],axis=1)

#sorting the values-Expensive countries to live in
data[['Country','City','Total Score']].sort_values(by='Total Score', ascending = False).head(10)
# Out:
#             Country           City  Total Score
# 144     Switzerland         Zurich     0.790375
# 78               NY       New York     0.670422
# 100              CA  San Francisco     0.660000
# 39        Singapore      Singapore     0.576437
# 70   United Kingdom         London     0.558841
# 128         Iceland      Reykjavik     0.557198
# 102              WA        Seattle     0.539670
# 50           Norway           Oslo     0.534259
# 47               MA         Boston     0.525962
# 71               CA    Los Angeles     0.487471

# %%
#sorting the values-Cheapest countries to live in
data[['Country','City','Total Score']].sort_values(by='Total Score', ascending = True).head(10)
# Out:
#        Country        City  Total Score
# 123      India     Kolkata     0.042501
# 106      India   Ahmedabad     0.043629
# 112      India     Chennai     0.056045
# 63     Georgia     Tbilisi     0.057976
# 118      India   Hyderabad     0.060394
# 81       India  Chandigarh     0.063713
# 130      India        Pune     0.069141
# 82   Sri Lanka     Colombo     0.069626
# 114      India       Delhi     0.070959
# 127      India      Mumbai     0.071562

# %% [markdown]
# ## Analysing Cost of essential items ##
# ### Also, printing out the countries and the cities wherein these essential items are expensive ###

# %%
#Analysing cost of essential items
#Basic amenities- electricity, water, taxi, groceries, milk, bread, eggs etc
x=city[['Country','City','Milk (regular), (1 liter)', 'Eggs (regular) (12)','Loaf of Fresh White Bread (500g)',
        'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)', 'Taxi 1km (Normal Tariff)','Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment']]

#Renaming the columns
x=x.rename(columns = {'Milk (regular), (1 liter)':'Milk','Eggs (regular) (12)':'Eggs','Loaf of Fresh White Bread (500g)':'Bread',
                     'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)':'Internet','Taxi 1km (Normal Tariff)':'Taxi Travel',
                     'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment':'Basic Amenities'})

x.head()
# Out:
#    Country              City  Milk  Eggs Bread Internet Taxi Travel  \
# 0   Russia  Saint Petersburg  0.98  1.18  0.71     6.96        0.26
# 1   Turkey          Istanbul  0.71  1.62  0.36     14.2        0.47
# 2   Turkey             Izmir  0.65  1.51  0.38    12.89        0.57
# 3  Finland          Helsinki  0.96  2.02  2.27    22.31           1
# 4  Moldova          Chisinau  0.68  1.11  0.33     8.58        0.18
#
#   Basic Amenities
# 0          102.17
# 1           59.33
# 2           51.07
# 3           82.66
# 4          113.46

# %%
#Summary statistics for the data
x[['Milk','Bread','Eggs','Internet','Taxi Travel','Basic Amenities']].astype('float').describe()
# Out:
#              Milk       Bread        Eggs    Internet  Taxi Travel  \
# count  160.000000  160.000000  160.000000  160.000000   160.000000
# mean     0.998938    1.197875    1.902812   29.660875     0.922250
# std      0.391720    0.760670    0.752520   18.908249     0.709011
# min      0.390000    0.100000    0.750000    4.440000     0.140000
# 25%      0.710000    0.555000    1.377500   12.832500     0.405000
# 50%      0.895000    1.020000    1.850000   26.615000     0.630000
# 75%      1.170000    1.690000    2.352500   43.317500     1.350000
# max      2.640000    3.330000    5.330000   93.290000     4.160000
#
#        Basic Amenities
# count       160.000000
# mean        107.106125
# std          51.553830
# min          18.560000
# 25%          63.860000
# 50%         102.465000
# 75%         145.707500
# max         265.520000

# %%
plt.rcParams['figure.figsize']=(10,3)

#checking countries where Milk is expensive
print(x[x['Milk']>1.17][['Country','City','Milk']].sort_values(by='Milk', ascending=False).head(5).set_index('Country'))
print('\n')

#checking countries where Bread is expensive
print(x[x['Bread']>1.69][['Country','City','Bread']].sort_values(by='Bread', ascending=False).head(5).set_index('Country'))
print('\n')

#checking countries where Eggs is expensive
print(x[x['Eggs']>2.35][['Country','City','Eggs']].sort_values(by='Eggs', ascending=False).head(5).set_index('Country'))
print('\n')

#checking countries where Internet is expensive
print(x[x['Internet']>43.31][['Country','City','Internet']].sort_values(by='Internet', ascending=False).head(5).set_index('Country'))
print('\n')

#checking countries where Taxi Travel is expensive
print(x[x['Taxi Travel']>1.35][['Country','City','Taxi Travel']].sort_values(by='Taxi Travel', ascending=False).head(5).set_index('Country'))
print('\n')

#checking countries where Basic Amenities is expensive
print(x[x['Basic Amenities']>145.70][['Country','City','Basic Amenities']].sort_values(by='Basic Amenities', ascending=False).head(5).set_index('Country'))
print('\n')
# Out:
#                   City  Milk
# Country
# Taiwan          Taipei  2.64
# Hong Kong    Hong Kong  2.54
# China         Shanghai  2.39
# Singapore    Singapore  2.04
# South Korea      Seoul  1.95
#
#
#                   City Bread
# Country
# NY            New York  3.33
# CA           San Diego  3.27
# CA       San Francisco  3.12
# CA         Los Angeles  2.99
# Norway            Oslo  2.92
#
#
#                   City  Eggs
# Country
# Switzerland     Zurich  5.33
# Iceland      Reykjavik   4.8
# Norway            Oslo  3.79
# France           Paris   3.4
# Israel       Jerusalem  3.32
#
#
#                            City Internet
# Country
# United Arab Emirates  Abu Dhabi    93.29
# United Arab Emirates      Dubai    90.42
# Qatar                      Doha    78.31
# AZ                      Phoenix    67.23
# Costa Rica             San Jose     65.3
#
#
#                              City Taxi Travel
# Country
# Switzerland                Zurich        4.16
# ...

# %% [markdown]
# ## Analyzing various other factors that would contribute to the quality of life in various places ##
# ### Reading the dataset

# %%
factors=pd.read_csv('otherfactors.csv')
factors.head()
# Out:
#            City  Movehub Rating  Purchase Power  Health Care  Pollution  \
# 0       Caracas           65.18           11.25        44.44      83.45
# 1  Johannesburg           84.08           53.99        59.98      47.39
# 2     Fortaleza           80.17           52.28        45.46      66.32
# 3   Saint Louis           85.25           80.40        77.29      31.33
# 4   Mexico City           75.07           24.28        61.76      18.95
#
#    Quality of Life  Crime Rating
# 0             8.61         85.70
# 1            51.26         83.93
# 2            36.68         78.65
# 3            87.51         78.13
# 4            27.91         77.86

# %% [markdown]
# ### Getting the statistical details of the dataframes using describe() ###

# %%
#Analyzing the various factors that describe the quality of life
factors.describe()
# Out:
#        Movehub Rating  Purchase Power  Health Care   Pollution  \
# count      216.000000      216.000000   216.000000  216.000000
# mean        79.676713       46.477176    66.442824   45.240370
# std          6.501011       20.614519    14.416412   25.369741
# min         59.880000        6.380000    20.830000    0.000000
# 25%         75.070000       28.815000    59.420000   24.410000
# 50%         81.060000       49.220000    67.685000   37.210000
# 75%         84.020000       61.607500    77.207500   67.675000
# max        100.000000       91.850000    95.960000   92.420000
#
#        Quality of Life  Crime Rating
# count       216.000000    216.000000
# mean         59.994537     41.338611
# std          22.019376     16.416409
# min           5.290000      9.110000
# 25%          42.752500     29.375000
# 50%          65.150000     41.140000
# 75%          78.617500     51.327500
# max          97.910000     85.700000

# %% [markdown]
# ### Analyzing parameters-Health care, Quality of Life and Crime Rate ###

# %%
#Analyzing health care
print("Cities having 'BEST' HEALTH CARE FACILITIES")
display(factors[['City','Health Care']].sort_values(by='Health Care', ascending=False).head(10).set_index('City').style.background_gradient(cmap='inferno'))

print("Cities having 'WORST' HEALTH CARE FACILITIES")
display(factors[['City','Health Care']].sort_values(by='Health Care', ascending=True).head(10).set_index('City').style.background_gradient(cmap='inferno'))
# Out:
# Cities having 'BEST' HEALTH CARE FACILITIES
# <style  type="text/css" >
# #T_d32e4ee9_d71a_11eb_968f_f8a2d6d10edbrow0_col0{
#             background-color:  #fcffa4;
#             color:  #000000;
#         }#T_d32e4ee9_d71a_11eb_968f_f8a2d6d10edbrow1_col0{
#             background-color:  #b3325a;
#             color:  #f1f1f1;
#         }#T_d32e4ee9_d71a_11eb_968f_f8a2d6d10edbrow2_col0{
#             background-color:  #9b2964;
#             color:  #f1f1f1;
#         }#T_d32e4ee9_d71a_11eb_968f_f8a2d6d10edbrow3_col0{
#             background-color:  #6c186e;
#             color:  #f1f1f1;
#         }#T_d32e4ee9_d71a_11eb_968f_f8a2d6d10edbrow4_col0,#T_d32e4ee9_d71a_11eb_968f_f8a2d6d10edbrow5_col0,#T_d32e4ee9_d71a_11eb_968f_f8a2d6d10edbrow6_col0{
#             background-color:  #140b34;
#             color:  #f1f1f1;
#         }#T_d32e4ee9_d71a_11eb_968f_f8a2d6d10edbrow7_col0{
#             background-color:  #0a0722;
#             color:  #f1f1f1;
# ...

# %%
#Analyzing quality of life
print("Cities having 'BEST' QUALITY OF LIFE")
display(factors[['City','Quality of Life']].sort_values(by='Quality of Life', ascending=False).head(10).set_index('City').style.background_gradient(cmap='Reds'))

print("Cities having 'WORST' QUALITY OF LIFE")
display(factors[['City','Quality of Life']].sort_values(by='Quality of Life', ascending=True).head(10).set_index('City').style.background_gradient(cmap='Reds'))
# Out:
# Cities having 'BEST' QUALITY OF LIFE
# <style  type="text/css" >
# #T_fc9aa0f4_d719_11eb_af79_f8a2d6d10edbrow0_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_fc9aa0f4_d719_11eb_af79_f8a2d6d10edbrow1_col0{
#             background-color:  #fb7353;
#             color:  #000000;
#         }#T_fc9aa0f4_d719_11eb_af79_f8a2d6d10edbrow2_col0{
#             background-color:  #fcaa8d;
#             color:  #000000;
#         }#T_fc9aa0f4_d719_11eb_af79_f8a2d6d10edbrow3_col0{
#             background-color:  #fcb79c;
#             color:  #000000;
#         }#T_fc9aa0f4_d719_11eb_af79_f8a2d6d10edbrow4_col0{
#             background-color:  #fdccb8;
#             color:  #000000;
#         }#T_fc9aa0f4_d719_11eb_af79_f8a2d6d10edbrow5_col0{
#             background-color:  #fdd1be;
#             color:  #000000;
#         }#T_fc9aa0f4_d719_11eb_af79_f8a2d6d10edbrow6_col0{
#             background-color:  #fdd7c6;
#             color:  #000000;
# ...

# %%
#Analyzing Crime Rating
print("Cities having 'HIGH' CRIME RATE")
display(factors[['City','Crime Rating']].sort_values(by='Crime Rating', ascending=False).head(10).set_index('City').style.background_gradient(cmap='bone'))

print("Cities having 'LOW' CRIME RATE")
display(factors[['City','Crime Rating']].sort_values(by='Crime Rating', ascending=True).head(10).set_index('City').style.background_gradient(cmap='bone'))
# Out:
# Cities having 'HIGH' CRIME RATE
# <style  type="text/css" >
# #T_381fc12a_d71b_11eb_a7f5_f8a2d6d10edbrow0_col0{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_381fc12a_d71b_11eb_a7f5_f8a2d6d10edbrow1_col0{
#             background-color:  #cadddd;
#             color:  #000000;
#         }#T_381fc12a_d71b_11eb_a7f5_f8a2d6d10edbrow2_col0{
#             background-color:  #565776;
#             color:  #f1f1f1;
#         }#T_381fc12a_d71b_11eb_a7f5_f8a2d6d10edbrow3_col0{
#             background-color:  #4b4b69;
#             color:  #f1f1f1;
#         }#T_381fc12a_d71b_11eb_a7f5_f8a2d6d10edbrow4_col0{
#             background-color:  #464661;
#             color:  #f1f1f1;
#         }#T_381fc12a_d71b_11eb_a7f5_f8a2d6d10edbrow5_col0{
#             background-color:  #2f2f42;
#             color:  #f1f1f1;
#         }#T_381fc12a_d71b_11eb_a7f5_f8a2d6d10edbrow6_col0{
#             background-color:  #2b2b3c;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# ## Recommendation of better places/cities

# %%
#Recommending Better places to live
def recommend_better_cities(urban,factor='Lifestyle'):
    x=city[['City','Food','Education','Lifestyle','Travel','Income']]
    food=x[x['City']==urban]['Food']
    edu=x[x['City']==urban]['Education']
    life=x[x['City']==urban]['Lifestyle']
    travel=x[x['City']==urban]['Travel']
    income=x[x['City']==urban]['Income']
    
    best_cities=x[(x['Food']<=food.values[0]) & (x['Education']<=edu.values[0]) &
                  (x['Lifestyle']<=life.values[0]) & (x['Travel']<=travel.values[0]) & (x['Income']>income.values[0])]
    best=best_cities.sort_values(by=factor,ascending=False).head(10)
    return best['City'].reset_index(drop=True)

# %%
recommend_better_cities('Sydney')
# Out:
# 0     Brisbane
# 1    Las Vegas
# Name: City, dtype: object

# %%
recommend_better_cities('Zurich')
# Out:
# 0    San Francisco
# Name: City, dtype: object
